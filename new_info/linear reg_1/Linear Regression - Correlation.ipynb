# %% [markdown]
# ## Linear Regression

# %%
Linearity:
    Coef of corr
    Pearson Corr Coeff
    R-Value
    -1 to +1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Iris.csv').sort_index(axis = 1)
df
# Out:
#      PetalLengthCm  PetalWidthCm  SepalWidthCm  Target
# 0              1.4           0.2           3.5     5.1
# 1              1.4           0.2           3.0     4.9
# 2              1.3           0.2           3.2     4.7
# 3              1.5           0.2           3.1     4.6
# 4              1.4           0.2           3.6     5.0
# ..             ...           ...           ...     ...
# 145            5.2           2.3           3.0     6.7
# 146            5.0           1.9           2.5     6.3
# 147            5.2           2.0           3.0     6.5
# 148            5.4           2.3           3.4     6.2
# 149            5.1           1.8           3.0     5.9
#
# [150 rows x 4 columns]

# %%
df.corr()
# Out:
#                PetalLengthCm  PetalWidthCm  SepalWidthCm    Target
# PetalLengthCm       1.000000      0.962757     -0.420516  0.871754
# PetalWidthCm        0.962757      1.000000     -0.356544  0.817954
# SepalWidthCm       -0.420516     -0.356544      1.000000 -0.109369
# Target              0.871754      0.817954     -0.109369  1.000000

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                PetalLengthCm  PetalWidthCm  SepalWidthCm    Target
# PetalLengthCm       1.000000      0.962757     -0.420516  0.871754
# PetalWidthCm        0.962757      1.000000     -0.356544  0.817954
# SepalWidthCm       -0.420516     -0.356544      1.000000 -0.109369
# Target              0.871754      0.817954     -0.109369  1.000000

# %%
sns.histplot(df['PetalLengthCm'])
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(df['PetalLengthCm'],kde=True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.kdeplot(df['PetalLengthCm'])
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>
